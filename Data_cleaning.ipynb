# %%
import pandas as pd

# %%
# List selected reports

reports = [ './/Resources/JC-202312-citibike-tripdata.csv',
            './/Resources/JC-202401-citibike-tripdata.csv',
            './/Resources/JC-202402-citibike-tripdata.csv',
            './/Resources/JC-202406-citibike-tripdata.csv',
            './/Resources/JC-202407-citibike-tripdata.csv',
            './/Resources/JC-202408-citibike-tripdata.csv',]

# %%
# Empty dataframe

citibike_df = pd.DataFrame()

# %%
# Loop through & concatonate files

for file in reports:
    data = pd.read_csv(file)
    citibike_df = pd.concat([citibike_df, data], axis=0)

citibike_df
# Out:
#                  ride_id  rideable_type               started_at  \
# 0       DAE3C13A5FAAB089   classic_bike      2023-12-29 16:02:20
# 1       1EC6BE46ACF2DE11   classic_bike      2023-12-06 01:58:32
# 2       105CA439B9CBF57C   classic_bike      2023-12-06 20:15:11
# 3       DC1C46F6090FA1DB   classic_bike      2023-12-09 13:54:19
# 4       04EAEAAD6D32A664   classic_bike      2023-12-02 17:30:34
# ...                  ...            ...                      ...
# 106446  2A2BA6BBA3573222  electric_bike  2024-08-04 08:42:32.158
# 106447  B506A92DA678BF5A   classic_bike  2024-08-20 14:35:33.862
# 106448  BCF510FEB63D4DD3  electric_bike  2024-08-27 15:26:31.489
# 106449  A9DD10B01D74BA40  electric_bike  2024-08-27 15:26:57.288
# 106450  061403E284F4B281   classic_bike  2024-08-27 07:25:09.826
#
#                        ended_at start_station_name start_station_id  \
# 0           2023-12-29 16:10:17       Brunswick St            JC023
# ...

# %%
citibike_df.to_csv('.///Clean_data.csv', index=False)
